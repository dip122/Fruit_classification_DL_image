# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_files
#from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import array_to_img, img_to_array, load_img
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D
from keras.layers import Activation, Dense, Flatten, Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from keras import backend as K
# Out:
# 2024-03-01 12:37:51.576303: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-01 12:37:51.576389: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-01 12:37:51.765993: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
train_data='/kaggle/input/fruits/fruits-360_dataset/fruits-360/Training'

# %%
test_data='/kaggle/input/fruits/fruits-360_dataset/fruits-360/Test'

# %%
def get_data(path):
    data = load_files(path)
    files = np.array(data['filenames'])
    targets = np.array(data['target'])
    target_labels = np.array(data['target_names'])
    return files,targets,target_labels

X_train, Y_train, labels = get_data(train_data)
X_test, Y_test,_ = get_data(test_data)

# %%
from keras.utils import to_categorical

# %%
Y_train = to_categorical(Y_train, 131)
Y_test = to_categorical(Y_test, 131)

# %%
X_train, X_val = train_test_split(X_train, test_size=0.2, random_state=33)
Y_train, Y_val = train_test_split(Y_train, test_size=0.2, random_state=33)

# %%
def convert_image_to_array(files):
    images_as_array=[]
    for file in files:
        images_as_array.append(img_to_array(load_img(file)))
    return images_as_array

# %%
X_train = np.array(convert_image_to_array(X_train))
X_val = np.array(convert_image_to_array(X_val))
X_test = np.array(convert_image_to_array(X_test))

# %%
X_train = X_train.astype('float32')/255
X_val = X_val.astype('float32')/255
X_test = X_test.astype('float32')/255

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, Activation, MaxPooling2D, Dropout, Flatten, Dense, Attention, Input

# Define the CNN model with attention
input_layer = Input(shape=(100, 100, 3))

# Convolutional layers
x = Conv2D(filters=16, kernel_size=2, padding='same')(input_layer)
x = Activation('relu')(x)
x = MaxPooling2D(pool_size=2)(x)

x = Conv2D(filters=32, kernel_size=2, activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=2)(x)

x = Conv2D(filters=64, kernel_size=2, activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=2)(x)

x = Conv2D(filters=128, kernel_size=2, activation='relu', padding='same')(x)
x = MaxPooling2D(pool_size=2)(x)

# Applying attention after the last convolutional layer
attention = Attention()([x, x])

# Fully connected layers
x = Dropout(0.3)(attention)
x = Flatten()(x)
x = Dense(150, activation='relu')(x)
x = Dropout(0.4)(x)
output_layer = Dense(131, activation='softmax')(x)

# Creating the model with attention
model_with_attention = Model(inputs=input_layer, outputs=output_layer)

# Displaying the summary of the model
model_with_attention.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 100, 100, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 100, 100, 16)         208       ['input_1[0][0]']
#
#  activation (Activation)     (None, 100, 100, 16)         0         ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 50, 50, 16)           0         ['activation[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 50, 50, 32)           2080      ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 25, 25, 32)           0         ['conv2d_1[0][0]']
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 64)           8256      ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 12, 12, 64)           0         ['conv2d_2[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)          32896     ['max_pooling2d_2[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 128)            0         ['conv2d_3[0][0]']
#  g2D)
#
#  attention (Attention)       (None, 6, 6, 128)            0         ['max_pooling2d_3[0][0]',
#                                                                      'max_pooling2d_3[0][0]']
#
#  dropout (Dropout)           (None, 6, 6, 128)            0         ['attention[0][0]']
#
#  flatten (Flatten)           (None, 4608)                 0         ['dropout[0][0]']
#
#  dense (Dense)               (None, 150)                  691350    ['flatten[0][0]']
#
#  dropout_1 (Dropout)         (None, 150)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 131)                  19781     ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 754571 (2.88 MB)
# Trainable params: 754571 (2.88 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
from keras.optimizers import SGD, Adam, RMSprop

optimizer = Adam()
model_with_attention.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
checkpointer = ModelCheckpoint(filepath = 'cnn_from_scratch_fruits.hdf5', verbose = 1, save_best_only = True)

# fitting model using above defined layers 
history = model_with_attention.fit(X_train,Y_train,
        batch_size = 128,
        epochs=25,
        validation_data=(X_val, Y_val),
        callbacks = [checkpointer],
        verbose=2, shuffle=True)
# Out:
# Epoch 1/25
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1709297649.718464     109 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# Epoch 1: val_loss improved from inf to 0.18225, saving model to cnn_from_scratch_fruits.hdf5
# 424/424 - 22s - loss: 2.2274 - accuracy: 0.4334 - val_loss: 0.1823 - val_accuracy: 0.9581 - 22s/epoch - 52ms/step
# Epoch 2/25
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 0.18225 to 0.04129, saving model to cnn_from_scratch_fruits.hdf5
# 424/424 - 10s - loss: 0.4154 - accuracy: 0.8623 - val_loss: 0.0413 - val_accuracy: 0.9910 - 10s/epoch - 25ms/step
# Epoch 3/25
#
# Epoch 3: val_loss improved from 0.04129 to 0.02881, saving model to cnn_from_scratch_fruits.hdf5
# 424/424 - 11s - loss: 0.2572 - accuracy: 0.9127 - val_loss: 0.0288 - val_accuracy: 0.9921 - 11s/epoch - 25ms/step
# Epoch 4/25
#
# Epoch 4: val_loss improved from 0.02881 to 0.01626, saving model to cnn_from_scratch_fruits.hdf5
# 424/424 - 11s - loss: 0.1957 - accuracy: 0.9317 - val_loss: 0.0163 - val_accuracy: 0.9952 - 11s/epoch - 25ms/step
# Epoch 5/25
#
# Epoch 5: val_loss improved from 0.01626 to 0.01000, saving model to cnn_from_scratch_fruits.hdf5
# 424/424 - 11s - loss: 0.1537 - accuracy: 0.9473 - val_loss: 0.0100 - val_accuracy: 0.9979 - 11s/epoch - 25ms/step
# Epoch 6/25
#
# Epoch 6: val_loss did not improve from 0.01000
# 424/424 - 11s - loss: 0.1388 - accuracy: 0.9526 - val_loss: 0.0150 - val_accuracy: 0.9959 - 11s/epoch - 25ms/step
# Epoch 7/25
#
# Epoch 7: val_loss did not improve from 0.01000
# 424/424 - 11s - loss: 0.1249 - accuracy: 0.9560 - val_loss: 0.0151 - val_accuracy: 0.9954 - 11s/epoch - 25ms/step
# Epoch 8/25
#
# Epoch 8: val_loss did not improve from 0.01000
# 424/424 - 11s - loss: 0.1250 - accuracy: 0.9574 - val_loss: 0.0344 - val_accuracy: 0.9865 - 11s/epoch - 26ms/step
# Epoch 9/25
#
# Epoch 9: val_loss improved from 0.01000 to 0.00484, saving model to cnn_from_scratch_fruits.hdf5
# 424/424 - 11s - loss: 0.1077 - accuracy: 0.9629 - val_loss: 0.0048 - val_accuracy: 0.9989 - 11s/epoch - 26ms/step
# Epoch 10/25
#
# Epoch 10: val_loss did not improve from 0.00484
# 424/424 - 11s - loss: 0.0923 - accuracy: 0.9684 - val_loss: 0.0049 - val_accuracy: 0.9988 - 11s/epoch - 25ms/step
# Epoch 11/25
#
# Epoch 11: val_loss did not improve from 0.00484
# 424/424 - 11s - loss: 0.0953 - accuracy: 0.9663 - val_loss: 0.0052 - val_accuracy: 0.9980 - 11s/epoch - 25ms/step
# Epoch 12/25
#
# Epoch 12: val_loss improved from 0.00484 to 0.00443, saving model to cnn_from_scratch_fruits.hdf5
# 424/424 - 11s - loss: 0.0929 - accuracy: 0.9681 - val_loss: 0.0044 - val_accuracy: 0.9990 - 11s/epoch - 25ms/step
# Epoch 13/25
#
# Epoch 13: val_loss did not improve from 0.00443
# 424/424 - 11s - loss: 0.0829 - accuracy: 0.9722 - val_loss: 0.0479 - val_accuracy: 0.9861 - 11s/epoch - 25ms/step
# Epoch 14/25
#
# Epoch 14: val_loss did not improve from 0.00443
# 424/424 - 11s - loss: 0.0868 - accuracy: 0.9711 - val_loss: 0.0065 - val_accuracy: 0.9974 - 11s/epoch - 25ms/step
# Epoch 15/25
#
# Epoch 15: val_loss improved from 0.00443 to 0.00226, saving model to cnn_from_scratch_fruits.hdf5
# 424/424 - 11s - loss: 0.0731 - accuracy: 0.9748 - val_loss: 0.0023 - val_accuracy: 0.9994 - 11s/epoch - 25ms/step
# Epoch 16/25
#
# Epoch 16: val_loss did not improve from 0.00226
# 424/424 - 11s - loss: 0.0640 - accuracy: 0.9779 - val_loss: 0.0158 - val_accuracy: 0.9939 - 11s/epoch - 25ms/step
# Epoch 17/25
#
# Epoch 17: val_loss improved from 0.00226 to 0.00087, saving model to cnn_from_scratch_fruits.hdf5
# 424/424 - 11s - loss: 0.0649 - accuracy: 0.9774 - val_loss: 8.6822e-04 - val_accuracy: 1.0000 - 11s/epoch - 25ms/step
# Epoch 18/25
#
# Epoch 18: val_loss did not improve from 0.00087
# 424/424 - 11s - loss: 0.0619 - accuracy: 0.9785 - val_loss: 0.0018 - val_accuracy: 0.9996 - 11s/epoch - 25ms/step
# Epoch 19/25
#
# Epoch 19: val_loss did not improve from 0.00087
# 424/424 - 11s - loss: 0.0645 - accuracy: 0.9785 - val_loss: 8.9928e-04 - val_accuracy: 0.9998 - 11s/epoch - 25ms/step
# Epoch 20/25
#
# Epoch 20: val_loss did not improve from 0.00087
# 424/424 - 11s - loss: 0.0556 - accuracy: 0.9804 - val_loss: 0.0011 - val_accuracy: 0.9997 - 11s/epoch - 25ms/step
# Epoch 21/25
#
# Epoch 21: val_loss improved from 0.00087 to 0.00038, saving model to cnn_from_scratch_fruits.hdf5
# 424/424 - 11s - loss: 0.0614 - accuracy: 0.9799 - val_loss: 3.7827e-04 - val_accuracy: 1.0000 - 11s/epoch - 25ms/step
# Epoch 22/25
#
# Epoch 22: val_loss did not improve from 0.00038
# 424/424 - 11s - loss: 0.0556 - accuracy: 0.9810 - val_loss: 0.0023 - val_accuracy: 0.9990 - 11s/epoch - 25ms/step
# Epoch 23/25
#
# Epoch 23: val_loss did not improve from 0.00038
# 424/424 - 11s - loss: 0.0514 - accuracy: 0.9823 - val_loss: 8.6152e-04 - val_accuracy: 0.9998 - 11s/epoch - 25ms/step
# Epoch 24/25
#
# Epoch 24: val_loss did not improve from 0.00038
# 424/424 - 11s - loss: 0.0521 - accuracy: 0.9822 - val_loss: 0.0026 - val_accuracy: 0.9992 - 11s/epoch - 25ms/step
# Epoch 25/25
#
# Epoch 25: val_loss improved from 0.00038 to 0.00016, saving model to cnn_from_scratch_fruits.hdf5
# 424/424 - 11s - loss: 0.0487 - accuracy: 0.9833 - val_loss: 1.5507e-04 - val_accuracy: 1.0000 - 11s/epoch - 25ms/step

# %%
score = model_with_attention.evaluate(X_test, Y_test)
print('Test accuracy:', score[1])
# Out:
# 709/709 [==============================] - 3s 4ms/step - loss: 0.1014 - accuracy: 0.9838
# Test accuracy: 0.9837799668312073

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'],color = 'red',label = 'training_acc')
plt.plot(history.history['val_accuracy'],color = 'blue',label = 'test_acc')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend()
plt.show()




plt.plot(history.history['loss'],color = 'red',label = 'training_loss')
plt.plot(history.history['val_loss'],color = 'blue',label = 'test_loss')
plt.ylabel('loss')
plt.xlabel('epochs')
plt.legend()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns


y_pred = model_with_attention.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)

confusion_mtx = confusion_matrix(np.argmax(Y_test, axis=1), y_pred_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

test_loss, test_acc = model_with_attention.evaluate(X_test, Y_test)
print(f"Test accuracy is {test_acc} and test loss is {test_loss}")
# Out:
# 709/709 [==============================] - 2s 3ms/step
# 709/709 [==============================] - 3s 5ms/step - loss: 0.1014 - accuracy: 0.9838
# Test accuracy is 0.9837799668312073 and test loss is 0.10136287659406662

# %%
from sklearn.metrics import classification_report, confusion_matrix

# Predictions on test set
Y_pred = model_with_attention.predict(X_test)
# Convert predictions to one-hot encoded labels
Y_pred_labels = np.argmax(Y_pred, axis=1)
Y_true_labels = np.argmax(Y_test, axis=1)

# Confusion Matrix
conf_matrix = confusion_matrix(Y_true_labels, Y_pred_labels)

# Classification Report
class_report = classification_report(Y_true_labels, Y_pred_labels)

print("Confusion Matrix:")
print(conf_matrix)

print("\nClassification Report:")
print(class_report)
# Out:
# 709/709 [==============================] - 2s 3ms/step
# Confusion Matrix:
# [[142   0   0 ...   0   0   0]
#  [  0 148   0 ...   0   0   0]
#  [  0   0 160 ...   0   0   0]
#  ...
#  [  0   0   0 ... 158   0   0]
#  [  0   0   0 ...   0 249   0]
#  [  0   0   0 ...   0   0 157]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93       164
#            1       1.00      1.00      1.00       148
#            2       1.00      1.00      1.00       160
#            3       0.99      1.00      1.00       164
#            4       1.00      1.00      1.00       161
#            5       1.00      1.00      1.00       164
#            6       0.81      1.00      0.89       152
#            7       0.92      1.00      0.96       164
#            8       1.00      1.00      1.00       164
#            9       1.00      0.99      1.00       144
#           10       1.00      1.00      1.00       166
#           11       1.00      0.99      1.00       164
#           12       1.00      1.00      1.00       219
#           13       1.00      1.00      1.00       164
#           14       1.00      1.00      1.00       143
#           15       1.00      1.00      1.00       166
#           16       1.00      0.97      0.98       166
#           17       1.00      1.00      1.00       152
#           18       0.94      0.97      0.95       166
#           19       1.00      0.99      0.99       150
#           20       1.00      0.68      0.81       154
#           21       0.95      1.00      0.97       166
#           22       1.00      1.00      1.00       164
#           23       0.96      0.99      0.98       164
#           24       1.00      0.95      0.97       166
#           25       0.97      1.00      0.99       234
#           26       1.00      1.00      1.00       164
#           27       1.00      1.00      1.00       246
#           28       1.00      0.88      0.94       246
#           29       1.00      1.00      1.00       164
#           30       1.00      1.00      1.00       164
#           31       1.00      1.00      1.00       164
#           32       0.92      0.99      0.95       153
#           33       1.00      0.99      1.00       166
#           34       1.00      0.99      1.00       166
#           35       0.99      0.65      0.78       150
#           36       1.00      0.76      0.86       154
#           37       1.00      1.00      1.00       130
#           38       1.00      1.00      1.00       156
#           39       0.97      1.00      0.99       166
#           40       0.98      0.75      0.85       156
#           41       1.00      1.00      1.00       234
#           42       1.00      1.00      1.00        99
#           43       1.00      1.00      1.00       166
#           44       0.87      1.00      0.93       328
#           45       1.00      1.00      1.00       164
#           46       0.95      1.00      0.97       166
#           47       1.00      1.00      1.00       166
#           48       1.00      1.00      1.00       164
#           49       1.00      1.00      1.00       158
#           50       1.00      1.00      1.00       166
#           51       1.00      1.00      1.00       164
#           52       1.00      1.00      1.00       166
#           53       0.99      1.00      1.00       157
#           54       1.00      1.00      1.00       166
#           55       0.99      1.00      1.00       166
#           56       1.00      1.00      1.00       156
#           57       0.99      1.00      0.99       157
#           58       1.00      1.00      1.00       166
#           59       1.00      1.00      1.00       164
#           60       1.00      1.00      1.00       166
#           61       1.00      1.00      1.00       166
#           62       1.00      1.00      1.00       166
#           63       1.00      1.00      1.00       166
#           64       1.00      1.00      1.00       166
#           65       1.00      1.00      1.00       142
#           66       1.00      0.88      0.94       102
#           67       1.00      0.99      1.00       166
#           68       1.00      1.00      1.00       246
#           69       1.00      1.00      1.00       164
#           70       0.88      1.00      0.94       164
#           71       1.00      1.00      1.00       160
#           72       1.00      1.00      1.00       218
#           73       1.00      1.00      1.00       178
#           74       1.00      1.00      1.00       150
#           75       1.00      1.00      1.00       155
#           76       0.84      1.00      0.92       146
#           77       1.00      1.00      1.00       160
#           78       1.00      1.00      1.00       164
#           79       1.00      1.00      1.00       166
#           80       0.99      0.91      0.95       164
#           81       0.86      1.00      0.93       246
#           82       1.00      1.00      1.00       164
#           83       1.00      1.00      1.00       164
#           84       1.00      0.74      0.85       232
#           85       1.00      0.91      0.95       166
#           86       1.00      1.00      1.00       234
#           87       1.00      1.00      1.00       102
#           88       0.97      1.00      0.99       166
#           89       1.00      1.00      1.00       222
#           90       0.83      1.00      0.91       237
#           91       0.99      1.00      1.00       166
#           92       0.87      0.99      0.93       166
#           93       1.00      1.00      1.00       148
#           94       1.00      1.00      1.00       234
#           95       1.00      1.00      1.00       222
#           96       1.00      1.00      1.00       222
#           97       1.00      1.00      1.00       164
#           98       0.96      0.99      0.98       164
#           99       1.00      1.00      1.00       166
#          100       1.00      1.00      1.00       163
#          101       1.00      0.99      1.00       166
#          102       1.00      1.00      1.00       151
#          103       1.00      1.00      1.00       142
#          104       1.00      1.00      1.00       304
#          105       1.00      1.00      1.00       164
#          106       1.00      1.00      1.00       153
#          107       1.00      1.00      1.00       150
#          108       1.00      1.00      1.00       151
#          109       1.00      0.99      0.99       150
#          110       0.99      1.00      1.00       150
#          111       1.00      1.00      1.00       166
#          112       0.99      1.00      1.00       164
#          113       1.00      1.00      1.00       166
#          114       1.00      1.00      1.00       164
#          115       0.99      1.00      0.99       162
#          116       1.00      1.00      1.00       164
#          117       1.00      0.99      0.99       246
#          118       1.00      1.00      1.00       166
#          119       0.99      1.00      1.00       166
#          120       1.00      1.00      1.00       246
#          121       1.00      1.00      1.00       225
#          122       1.00      1.00      1.00       246
#          123       1.00      1.00      1.00       160
#          124       1.00      1.00      1.00       164
#          125       1.00      1.00      1.00       228
#          126       1.00      1.00      1.00       127
#          127       1.00      1.00      1.00       153
#          128       0.95      1.00      0.97       158
#          129       1.00      1.00      1.00       249
#          130       0.92      1.00      0.96       157
#
#     accuracy                           0.98     22688
#    macro avg       0.99      0.98      0.98     22688
# weighted avg       0.99      0.98      0.98     22688
